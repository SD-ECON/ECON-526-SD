# %%
from graphviz import Digraph

i = Digraph()
i.edge('Industry Input Price', 'Price of Final Goods')
i.edge('Labour Expenses/Wages', 'Industry Input Price')
i.edge('Labour Expenses/Wages', 'Price of Final Goods') 
i.edge('Gasoline Price', 'Transportation Cost')
i.edge('Labour Expenses/Wages', 'Transportation Cost')
i.edge('Transportation Cost', 'Industry Input Price')
i.edge('Transportation Cost', 'Price of Final Goods')
i.edge('Labour Expenses/Wages', 'Household Consumption/Demand')
i.edge('Household Consumption/Demand', 'Price of Final Goods')
i.edge('Available Supply of Inputs', 'Industry Input Price')
i.edge('International Demand (Net Exports)', 'Price of Final Goods')
i.edge('Oil Price', 'Gasoline Price')
i.edge('Oil Price', 'CDN Exchange Rate')
i.edge('CDN Exchange Rate', 'Price of Final Goods')
i.edge('CDN Exchange Rate', 'International Demand (Net Exports)')
i.edge('Gasoline Price', 'Price of Final Goods')
#i.edge('Gasoline Price', 'Labour Expenses/Wages')
i.edge('Household Consumption/Demand', 'Gasoline Price')


i
